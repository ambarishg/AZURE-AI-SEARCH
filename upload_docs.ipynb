# %% [markdown]
# ### IMPORTS

# %%
import os
import argparse
import glob
import html
import io
import re
import time
from pypdf import PdfReader, PdfWriter
from azure.identity import AzureDeveloperCliCredential
from azure.core.credentials import AzureKeyCredential
from azure.storage.blob import BlobServiceClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import *
from azure.search.documents import SearchClient
from azure.ai.formrecognizer import DocumentAnalysisClient

# %%
from config import *
# Out:
# azure-ai-search-rag-demo-magnus
# test

# %%
search_creds = AzureKeyCredential(searchkey)
storage_creds = storagekey

# %%
MAX_SECTION_LENGTH = 1000
SENTENCE_SEARCH_LIMIT = 100
SECTION_OVERLAP = 100

# %% [markdown]
# ### FUNCTIONS

# %%
def blob_name_from_file_page(filename, page = 0):
    if os.path.splitext(filename)[1].lower() == ".pdf":
        return os.path.splitext(os.path.basename(filename))[0] + f"-{page}" + ".pdf"
    else:
        return os.path.basename(filename)

# %%
def upload_blobs(filename):
    blob_service = BlobServiceClient(account_url=f"https://{storageaccount}.blob.core.windows.net", credential=storage_creds)
    blob_container = blob_service.get_container_client(container)
    if not blob_container.exists():
        blob_container.create_container()

    # if file is PDF split into pages and upload each page as a separate blob
    if os.path.splitext(filename)[1].lower() == ".pdf":
        reader = PdfReader(filename)
        pages = reader.pages
        for i in range(len(pages)):
            blob_name = blob_name_from_file_page(filename, i)
            if verbose: print(f"\tUploading blob for page {i} -> {blob_name}")
            f = io.BytesIO()
            writer = PdfWriter()
            writer.add_page(pages[i])
            writer.write(f)
            f.seek(0)
            blob_container.upload_blob(blob_name, f, overwrite=True)
    else:
        blob_name = blob_name_from_file_page(filename)
        with open(filename,"rb") as data:
            blob_container.upload_blob(blob_name, data, overwrite=True)


def table_to_html(table):
    table_html = "<table>"
    rows = [sorted([cell for cell in table.cells if cell.row_index == i], key=lambda cell: cell.column_index) for i in range(table.row_count)]
    for row_cells in rows:
        table_html += "<tr>"
        for cell in row_cells:
            tag = "th" if (cell.kind == "columnHeader" or cell.kind == "rowHeader") else "td"
            cell_spans = ""
            if cell.column_span > 1: cell_spans += f" colSpan={cell.column_span}"
            if cell.row_span > 1: cell_spans += f" rowSpan={cell.row_span}"
            table_html += f"<{tag}{cell_spans}>{html.escape(cell.content)}</{tag}>"
        table_html +="</tr>"
    table_html += "</table>"
    return table_html

def get_document_text(filename):
    offset = 0
    page_map = []
    if localpdfparser:
        reader = PdfReader(filename)
        pages = reader.pages
        for page_num, p in enumerate(pages):
            page_text = p.extract_text()
            page_map.append((page_num, offset, page_text))
            offset += len(page_text)
    else:
        if verbose: print(f"Extracting text from '{filename}' using Azure Form Recognizer")
        form_recognizer_client = DocumentAnalysisClient(endpoint=f"https://{formrecognizerservice}.cognitiveservices.azure.com/", credential=formrecognizer_creds, headers={"x-ms-useragent": "azure-search-chat-demo/1.0.0"})
        with open(filename, "rb") as f:
            poller = form_recognizer_client.begin_analyze_document("prebuilt-layout", document = f)
        form_recognizer_results = poller.result()

        for page_num, page in enumerate(form_recognizer_results.pages):
            tables_on_page = [table for table in form_recognizer_results.tables if table.bounding_regions[0].page_number == page_num + 1]

            # mark all positions of the table spans in the page
            page_offset = page.spans[0].offset
            page_length = page.spans[0].length
            table_chars = [-1]*page_length
            for table_id, table in enumerate(tables_on_page):
                for span in table.spans:
                    # replace all table spans with "table_id" in table_chars array
                    for i in range(span.length):
                        idx = span.offset - page_offset + i
                        if idx >=0 and idx < page_length:
                            table_chars[idx] = table_id

            # build page text by replacing charcters in table spans with table html
            page_text = ""
            added_tables = set()
            for idx, table_id in enumerate(table_chars):
                if table_id == -1:
                    page_text += form_recognizer_results.content[page_offset + idx]
                elif not table_id in added_tables:
                    page_text += table_to_html(tables_on_page[table_id])
                    added_tables.add(table_id)

            page_text += " "
            page_map.append((page_num, offset, page_text))
            offset += len(page_text)

    return page_map

# %%
def split_text(page_map):
    SENTENCE_ENDINGS = [".", "!", "?"]
    WORDS_BREAKS = [",", ";", ":", " ", "(", ")", "[", "]", "{", "}", "\t", "\n"]
    if verbose: print(f"Splitting '{filename}' into sections")

    def find_page(offset):
        l = len(page_map)
        for i in range(l - 1):
            if offset >= page_map[i][1] and offset < page_map[i + 1][1]:
                return i
        return l - 1

    all_text = "".join(p[2] for p in page_map)
    length = len(all_text)
    start = 0
    end = length
    while start + SECTION_OVERLAP < length:
        last_word = -1
        end = start + MAX_SECTION_LENGTH

        if end > length:
            end = length
        else:
            # Try to find the end of the sentence
            while end < length and (end - start - MAX_SECTION_LENGTH) < SENTENCE_SEARCH_LIMIT and all_text[end] not in SENTENCE_ENDINGS:
                if all_text[end] in WORDS_BREAKS:
                    last_word = end
                end += 1
            if end < length and all_text[end] not in SENTENCE_ENDINGS and last_word > 0:
                end = last_word # Fall back to at least keeping a whole word
        if end < length:
            end += 1

        # Try to find the start of the sentence or at least a whole word boundary
        last_word = -1
        while start > 0 and start > end - MAX_SECTION_LENGTH - 2 * SENTENCE_SEARCH_LIMIT and all_text[start] not in SENTENCE_ENDINGS:
            if all_text[start] in WORDS_BREAKS:
                last_word = start
            start -= 1
        if all_text[start] not in SENTENCE_ENDINGS and last_word > 0:
            start = last_word
        if start > 0:
            start += 1

        section_text = all_text[start:end]
        yield (section_text, find_page(start))

        last_table_start = section_text.rfind("<table")
        if (last_table_start > 2 * SENTENCE_SEARCH_LIMIT and last_table_start > section_text.rfind("</table")):
            # If the section ends with an unclosed table, we need to start the next section with the table.
            # If table starts inside SENTENCE_SEARCH_LIMIT, we ignore it, as that will cause an infinite loop for tables longer than MAX_SECTION_LENGTH
            # If last table starts inside SECTION_OVERLAP, keep overlapping
            if verbose: print(f"Section ends with unclosed table, starting next section with the table at page {find_page(start)} offset {start} table start {last_table_start}")
            start = min(end - SECTION_OVERLAP, start + last_table_start)
        else:
            start = end - SECTION_OVERLAP
        
    if start + SECTION_OVERLAP < end:
        yield (all_text[start:end], find_page(start))

def create_sections(filename, page_map):
    for i, (section, pagenum) in enumerate(split_text(page_map)):
        yield {
            "id": re.sub("[^0-9a-zA-Z_-]","_",f"{filename}-{i}"),
            "content": section,
            "category": category,
            "sourcepage": blob_name_from_file_page(filename, pagenum),
            "sourcefile": filename
        }

def create_search_index():
    if verbose: print(f"Ensuring search index {index} exists")
    index_client = SearchIndexClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                     credential=search_creds)
    if index not in index_client.list_index_names():
        search_index = SearchIndex(
            name=index,
            fields=[
                SimpleField(name="id", type="Edm.String", key=True),
                SearchableField(name="content", type="Edm.String", analyzer_name="en.microsoft"),
                SimpleField(name="category", type="Edm.String", filterable=True, facetable=True),
                SimpleField(name="sourcepage", type="Edm.String", filterable=True, facetable=True),
                SimpleField(name="sourcefile", type="Edm.String", filterable=True, facetable=True)
            ],
            semantic_settings=SemanticSettings(
                configurations=[SemanticConfiguration(
                    name='default',
                    prioritized_fields=PrioritizedFields(
                        title_field=None, prioritized_content_fields=[SemanticField(field_name='content')]))])
        )
        if verbose: print(f"Creating {index} search index")
        index_client.create_index(search_index)
    else:
        if verbose: print(f"Search index {index} already exists")

def index_sections(filename, sections):
    if verbose: print(f"Indexing sections from '{filename}' into search index '{index}'")
    search_client = SearchClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                    index_name=index,
                                    credential=search_creds)
    i = 0
    batch = []
    for s in sections:
        batch.append(s)
        i += 1
        if i % 1000 == 0:
            results = search_client.upload_documents(documents=batch)
            succeeded = sum([1 for r in results if r.succeeded])
            if verbose: print(f"\tIndexed {len(results)} sections, {succeeded} succeeded")
            batch = []

    if len(batch) > 0:
        results = search_client.upload_documents(documents=batch)
        succeeded = sum([1 for r in results if r.succeeded])
        if verbose: print(f"\tIndexed {len(results)} sections, {succeeded} succeeded")

def remove_from_index(filename):
    if verbose: print(f"Removing sections from '{filename or '<all>'}' from search index '{index}'")
    search_client = SearchClient(endpoint=f"https://{searchservice}.search.windows.net/",
                                    index_name=index,
                                    credential=search_creds)
    while True:
        filter = None if filename == None else f"sourcefile eq '{os.path.basename(filename)}'"
        r = search_client.search("", filter=filter, top=1000, include_total_count=True)
        if r.get_count() == 0:
            break
        r = search_client.delete_documents(documents=[{ "id": d["id"] } for d in r])
        if verbose: print(f"\tRemoved {len(r)} sections from index")
        # It can take a few seconds for search results to reflect changes, so wait a bit
        time.sleep(2)

# %%
create_search_index()
# Out:
# Ensuring search index test exists
# Creating test search index

# %%
FILE_PATH
# Out:
# 'C:\\Users\\srely\\Repos\\AZURE-AI-SEARCH\\Data'

# %%
for filename in glob.glob(FILE_PATH + "/*.pdf"):
    if verbose: print(f"Processing '{filename}'")
    upload_blobs(filename)
    page_map = get_document_text(filename)
    sections = create_sections(filename, page_map)
    index_sections(filename, sections)
# Out:
# Processing 'C:\Users\srely\Repos\AZURE-AI-SEARCH\Data\Azure_For_Architects_compressed.pdf'
# 	Uploading blob for page 0 -> Azure_For_Architects_compressed-0.pdf
# 	Uploading blob for page 1 -> Azure_For_Architects_compressed-1.pdf
# 	Uploading blob for page 2 -> Azure_For_Architects_compressed-2.pdf
# 	Uploading blob for page 3 -> Azure_For_Architects_compressed-3.pdf
# 	Uploading blob for page 4 -> Azure_For_Architects_compressed-4.pdf
# 	Uploading blob for page 5 -> Azure_For_Architects_compressed-5.pdf
# 	Uploading blob for page 6 -> Azure_For_Architects_compressed-6.pdf
# 	Uploading blob for page 7 -> Azure_For_Architects_compressed-7.pdf
# 	Uploading blob for page 8 -> Azure_For_Architects_compressed-8.pdf
# 	Uploading blob for page 9 -> Azure_For_Architects_compressed-9.pdf
# 	Uploading blob for page 10 -> Azure_For_Architects_compressed-10.pdf
# 	Uploading blob for page 11 -> Azure_For_Architects_compressed-11.pdf
# 	Uploading blob for page 12 -> Azure_For_Architects_compressed-12.pdf
# 	Uploading blob for page 13 -> Azure_For_Architects_compressed-13.pdf
# 	Uploading blob for page 14 -> Azure_For_Architects_compressed-14.pdf
# 	Uploading blob for page 15 -> Azure_For_Architects_compressed-15.pdf
# 	Uploading blob for page 16 -> Azure_For_Architects_compressed-16.pdf
# 	Uploading blob for page 17 -> Azure_For_Architects_compressed-17.pdf
# 	Uploading blob for page 18 -> Azure_For_Architects_compressed-18.pdf
# 	Uploading blob for page 19 -> Azure_For_Architects_compressed-19.pdf
# 	Uploading blob for page 20 -> Azure_For_Architects_compressed-20.pdf
# 	Uploading blob for page 21 -> Azure_For_Architects_compressed-21.pdf
# 	Uploading blob for page 22 -> Azure_For_Architects_compressed-22.pdf
# 	Uploading blob for page 23 -> Azure_For_Architects_compressed-23.pdf
# 	Uploading blob for page 24 -> Azure_For_Architects_compressed-24.pdf
# 	Uploading blob for page 25 -> Azure_For_Architects_compressed-25.pdf
# 	Uploading blob for page 26 -> Azure_For_Architects_compressed-26.pdf
# 	Uploading blob for page 27 -> Azure_For_Architects_compressed-27.pdf
# 	Uploading blob for page 28 -> Azure_For_Architects_compressed-28.pdf
# 	Uploading blob for page 29 -> Azure_For_Architects_compressed-29.pdf
# 	Uploading blob for page 30 -> Azure_For_Architects_compressed-30.pdf
# 	Uploading blob for page 31 -> Azure_For_Architects_compressed-31.pdf
# 	Uploading blob for page 32 -> Azure_For_Architects_compressed-32.pdf
# 	Uploading blob for page 33 -> Azure_For_Architects_compressed-33.pdf
# 	Uploading blob for page 34 -> Azure_For_Architects_compressed-34.pdf
# 	Uploading blob for page 35 -> Azure_For_Architects_compressed-35.pdf
# 	Uploading blob for page 36 -> Azure_For_Architects_compressed-36.pdf
# 	Uploading blob for page 37 -> Azure_For_Architects_compressed-37.pdf
# 	Uploading blob for page 38 -> Azure_For_Architects_compressed-38.pdf
# 	Uploading blob for page 39 -> Azure_For_Architects_compressed-39.pdf
# 	Uploading blob for page 40 -> Azure_For_Architects_compressed-40.pdf
# 	Uploading blob for page 41 -> Azure_For_Architects_compressed-41.pdf
# 	Uploading blob for page 42 -> Azure_For_Architects_compressed-42.pdf
# 	Uploading blob for page 43 -> Azure_For_Architects_compressed-43.pdf
# 	Uploading blob for page 44 -> Azure_For_Architects_compressed-44.pdf
# 	Uploading blob for page 45 -> Azure_For_Architects_compressed-45.pdf
# 	Uploading blob for page 46 -> Azure_For_Architects_compressed-46.pdf
# 	Uploading blob for page 47 -> Azure_For_Architects_compressed-47.pdf
# 	Uploading blob for page 48 -> Azure_For_Architects_compressed-48.pdf
# 	Uploading blob for page 49 -> Azure_For_Architects_compressed-49.pdf
# 	Uploading blob for page 50 -> Azure_For_Architects_compressed-50.pdf
# 	Uploading blob for page 51 -> Azure_For_Architects_compressed-51.pdf
# 	Uploading blob for page 52 -> Azure_For_Architects_compressed-52.pdf
# 	Uploading blob for page 53 -> Azure_For_Architects_compressed-53.pdf
# 	Uploading blob for page 54 -> Azure_For_Architects_compressed-54.pdf
# 	Uploading blob for page 55 -> Azure_For_Architects_compressed-55.pdf
# 	Uploading blob for page 56 -> Azure_For_Architects_compressed-56.pdf
# 	Uploading blob for page 57 -> Azure_For_Architects_compressed-57.pdf
# 	Uploading blob for page 58 -> Azure_For_Architects_compressed-58.pdf
# 	Uploading blob for page 59 -> Azure_For_Architects_compressed-59.pdf
# 	Uploading blob for page 60 -> Azure_For_Architects_compressed-60.pdf
# 	Uploading blob for page 61 -> Azure_For_Architects_compressed-61.pdf
# 	Uploading blob for page 62 -> Azure_For_Architects_compressed-62.pdf
# 	Uploading blob for page 63 -> Azure_For_Architects_compressed-63.pdf
# 	Uploading blob for page 64 -> Azure_For_Architects_compressed-64.pdf
# 	Uploading blob for page 65 -> Azure_For_Architects_compressed-65.pdf
# 	Uploading blob for page 66 -> Azure_For_Architects_compressed-66.pdf
# 	Uploading blob for page 67 -> Azure_For_Architects_compressed-67.pdf
# 	Uploading blob for page 68 -> Azure_For_Architects_compressed-68.pdf
# 	Uploading blob for page 69 -> Azure_For_Architects_compressed-69.pdf
# 	Uploading blob for page 70 -> Azure_For_Architects_compressed-70.pdf
# 	Uploading blob for page 71 -> Azure_For_Architects_compressed-71.pdf
# 	Uploading blob for page 72 -> Azure_For_Architects_compressed-72.pdf
# 	Uploading blob for page 73 -> Azure_For_Architects_compressed-73.pdf
# 	Uploading blob for page 74 -> Azure_For_Architects_compressed-74.pdf
# 	Uploading blob for page 75 -> Azure_For_Architects_compressed-75.pdf
# 	Uploading blob for page 76 -> Azure_For_Architects_compressed-76.pdf
# 	Uploading blob for page 77 -> Azure_For_Architects_compressed-77.pdf
# 	Uploading blob for page 78 -> Azure_For_Architects_compressed-78.pdf
# 	Uploading blob for page 79 -> Azure_For_Architects_compressed-79.pdf
# 	Uploading blob for page 80 -> Azure_For_Architects_compressed-80.pdf
# 	Uploading blob for page 81 -> Azure_For_Architects_compressed-81.pdf
# 	Uploading blob for page 82 -> Azure_For_Architects_compressed-82.pdf
# 	Uploading blob for page 83 -> Azure_For_Architects_compressed-83.pdf
# 	Uploading blob for page 84 -> Azure_For_Architects_compressed-84.pdf
# 	Uploading blob for page 85 -> Azure_For_Architects_compressed-85.pdf
# 	Uploading blob for page 86 -> Azure_For_Architects_compressed-86.pdf
# 	Uploading blob for page 87 -> Azure_For_Architects_compressed-87.pdf
# 	Uploading blob for page 88 -> Azure_For_Architects_compressed-88.pdf
# 	Uploading blob for page 89 -> Azure_For_Architects_compressed-89.pdf
# 	Uploading blob for page 90 -> Azure_For_Architects_compressed-90.pdf
# 	Uploading blob for page 91 -> Azure_For_Architects_compressed-91.pdf
# 	Uploading blob for page 92 -> Azure_For_Architects_compressed-92.pdf
# 	Uploading blob for page 93 -> Azure_For_Architects_compressed-93.pdf
# 	Uploading blob for page 94 -> Azure_For_Architects_compressed-94.pdf
# 	Uploading blob for page 139 -> Azure_For_Architects_compressed-139.pdf
# 	Uploading blob for page 140 -> Azure_For_Architects_compressed-140.pdf
# 	Uploading blob for page 141 -> Azure_For_Architects_compressed-141.pdf
# 	Uploading blob for page 142 -> Azure_For_Architects_compressed-142.pdf
# 	Uploading blob for page 143 -> Azure_For_Architects_compressed-143.pdf
# 	Uploading blob for page 144 -> Azure_For_Architects_compressed-144.pdf
# 	Uploading blob for page 145 -> Azure_For_Architects_compressed-145.pdf
# 	Uploading blob for page 146 -> Azure_For_Architects_compressed-146.pdf
# 	Uploading blob for page 147 -> Azure_For_Architects_compressed-147.pdf
# 	Uploading blob for page 148 -> Azure_For_Architects_compressed-148.pdf
# 	Uploading blob for page 149 -> Azure_For_Architects_compressed-149.pdf
# 	Uploading blob for page 150 -> Azure_For_Architects_compressed-150.pdf
# 	Uploading blob for page 151 -> Azure_For_Architects_compressed-151.pdf
# 	Uploading blob for page 152 -> Azure_For_Architects_compressed-152.pdf
# 	Uploading blob for page 153 -> Azure_For_Architects_compressed-153.pdf
# 	Uploading blob for page 154 -> Azure_For_Architects_compressed-154.pdf
# 	Uploading blob for page 155 -> Azure_For_Architects_compressed-155.pdf
# 	Uploading blob for page 156 -> Azure_For_Architects_compressed-156.pdf
# 	Uploading blob for page 157 -> Azure_For_Architects_compressed-157.pdf
# 	Uploading blob for page 158 -> Azure_For_Architects_compressed-158.pdf
# 	Uploading blob for page 159 -> Azure_For_Architects_compressed-159.pdf
# 	Uploading blob for page 160 -> Azure_For_Architects_compressed-160.pdf
# 	Uploading blob for page 161 -> Azure_For_Architects_compressed-161.pdf
# 	Uploading blob for page 162 -> Azure_For_Architects_compressed-162.pdf
# 	Uploading blob for page 163 -> Azure_For_Architects_compressed-163.pdf
# 	Uploading blob for page 164 -> Azure_For_Architects_compressed-164.pdf
# 	Uploading blob for page 165 -> Azure_For_Architects_compressed-165.pdf
# 	Uploading blob for page 166 -> Azure_For_Architects_compressed-166.pdf
# 	Uploading blob for page 167 -> Azure_For_Architects_compressed-167.pdf
# 	Uploading blob for page 168 -> Azure_For_Architects_compressed-168.pdf
# 	Uploading blob for page 169 -> Azure_For_Architects_compressed-169.pdf
# 	Uploading blob for page 170 -> Azure_For_Architects_compressed-170.pdf
# 	Uploading blob for page 171 -> Azure_For_Architects_compressed-171.pdf
# 	Uploading blob for page 172 -> Azure_For_Architects_compressed-172.pdf
# 	Uploading blob for page 173 -> Azure_For_Architects_compressed-173.pdf
# 	Uploading blob for page 174 -> Azure_For_Architects_compressed-174.pdf
# 	Uploading blob for page 175 -> Azure_For_Architects_compressed-175.pdf
# 	Uploading blob for page 176 -> Azure_For_Architects_compressed-176.pdf
# 	Uploading blob for page 177 -> Azure_For_Architects_compressed-177.pdf
# 	Uploading blob for page 178 -> Azure_For_Architects_compressed-178.pdf
# 	Uploading blob for page 179 -> Azure_For_Architects_compressed-179.pdf
# 	Uploading blob for page 180 -> Azure_For_Architects_compressed-180.pdf
# 	Uploading blob for page 181 -> Azure_For_Architects_compressed-181.pdf
# 	Uploading blob for page 182 -> Azure_For_Architects_compressed-182.pdf
# 	Uploading blob for page 183 -> Azure_For_Architects_compressed-183.pdf
# 	Uploading blob for page 184 -> Azure_For_Architects_compressed-184.pdf
# 	Uploading blob for page 185 -> Azure_For_Architects_compressed-185.pdf
# 	Uploading blob for page 186 -> Azure_For_Architects_compressed-186.pdf
# 	Uploading blob for page 187 -> Azure_For_Architects_compressed-187.pdf
# 	Uploading blob for page 188 -> Azure_For_Architects_compressed-188.pdf
# 	Uploading blob for page 189 -> Azure_For_Architects_compressed-189.pdf
# 	Uploading blob for page 190 -> Azure_For_Architects_compressed-190.pdf
# 	Uploading blob for page 191 -> Azure_For_Architects_compressed-191.pdf
# 	Uploading blob for page 192 -> Azure_For_Architects_compressed-192.pdf
# 	Uploading blob for page 193 -> Azure_For_Architects_compressed-193.pdf
# 	Uploading blob for page 194 -> Azure_For_Architects_compressed-194.pdf
# 	Uploading blob for page 195 -> Azure_For_Architects_compressed-195.pdf
# 	Uploading blob for page 196 -> Azure_For_Architects_compressed-196.pdf
# 	Uploading blob for page 197 -> Azure_For_Architects_compressed-197.pdf
# 	Uploading blob for page 198 -> Azure_For_Architects_compressed-198.pdf
# 	Uploading blob for page 199 -> Azure_For_Architects_compressed-199.pdf
# 	Uploading blob for page 200 -> Azure_For_Architects_compressed-200.pdf
# 	Uploading blob for page 201 -> Azure_For_Architects_compressed-201.pdf
# 	Uploading blob for page 202 -> Azure_For_Architects_compressed-202.pdf
# 	Uploading blob for page 203 -> Azure_For_Architects_compressed-203.pdf
# 	Uploading blob for page 204 -> Azure_For_Architects_compressed-204.pdf
# 	Uploading blob for page 205 -> Azure_For_Architects_compressed-205.pdf
# 	Uploading blob for page 206 -> Azure_For_Architects_compressed-206.pdf
# 	Uploading blob for page 207 -> Azure_For_Architects_compressed-207.pdf
# 	Uploading blob for page 208 -> Azure_For_Architects_compressed-208.pdf
# 	Uploading blob for page 209 -> Azure_For_Architects_compressed-209.pdf
# 	Uploading blob for page 210 -> Azure_For_Architects_compressed-210.pdf
# 	Uploading blob for page 211 -> Azure_For_Architects_compressed-211.pdf
# 	Uploading blob for page 212 -> Azure_For_Architects_compressed-212.pdf
# 	Uploading blob for page 213 -> Azure_For_Architects_compressed-213.pdf
# 	Uploading blob for page 214 -> Azure_For_Architects_compressed-214.pdf
# 	Uploading blob for page 215 -> Azure_For_Architects_compressed-215.pdf
# 	Uploading blob for page 216 -> Azure_For_Architects_compressed-216.pdf
# 	Uploading blob for page 217 -> Azure_For_Architects_compressed-217.pdf
# 	Uploading blob for page 218 -> Azure_For_Architects_compressed-218.pdf
# 	Uploading blob for page 219 -> Azure_For_Architects_compressed-219.pdf
# 	Uploading blob for page 220 -> Azure_For_Architects_compressed-220.pdf
# 	Uploading blob for page 221 -> Azure_For_Architects_compressed-221.pdf
# 	Uploading blob for page 222 -> Azure_For_Architects_compressed-222.pdf
# 	Uploading blob for page 223 -> Azure_For_Architects_compressed-223.pdf
# 	Uploading blob for page 224 -> Azure_For_Architects_compressed-224.pdf
# 	Uploading blob for page 225 -> Azure_For_Architects_compressed-225.pdf
# 	Uploading blob for page 357 -> Azure_For_Architects_compressed-357.pdf
# 	Uploading blob for page 358 -> Azure_For_Architects_compressed-358.pdf
# 	Uploading blob for page 359 -> Azure_For_Architects_compressed-359.pdf
# 	Uploading blob for page 360 -> Azure_For_Architects_compressed-360.pdf
# 	Uploading blob for page 361 -> Azure_For_Architects_compressed-361.pdf
# 	Uploading blob for page 362 -> Azure_For_Architects_compressed-362.pdf
# 	Uploading blob for page 363 -> Azure_For_Architects_compressed-363.pdf
# 	Uploading blob for page 364 -> Azure_For_Architects_compressed-364.pdf
# 	Uploading blob for page 365 -> Azure_For_Architects_compressed-365.pdf
# 	Uploading blob for page 366 -> Azure_For_Architects_compressed-366.pdf
# 	Uploading blob for page 367 -> Azure_For_Architects_compressed-367.pdf
# 	Uploading blob for page 368 -> Azure_For_Architects_compressed-368.pdf
# 	Uploading blob for page 369 -> Azure_For_Architects_compressed-369.pdf
# 	Uploading blob for page 370 -> Azure_For_Architects_compressed-370.pdf
# 	Uploading blob for page 371 -> Azure_For_Architects_compressed-371.pdf
# 	Uploading blob for page 372 -> Azure_For_Architects_compressed-372.pdf
# 	Uploading blob for page 373 -> Azure_For_Architects_compressed-373.pdf
# 	Uploading blob for page 374 -> Azure_For_Architects_compressed-374.pdf
# 	Uploading blob for page 375 -> Azure_For_Architects_compressed-375.pdf
# 	Uploading blob for page 376 -> Azure_For_Architects_compressed-376.pdf
# 	Uploading blob for page 377 -> Azure_For_Architects_compressed-377.pdf
# 	Uploading blob for page 378 -> Azure_For_Architects_compressed-378.pdf
# 	Uploading blob for page 379 -> Azure_For_Architects_compressed-379.pdf
# 	Uploading blob for page 380 -> Azure_For_Architects_compressed-380.pdf
# 	Uploading blob for page 381 -> Azure_For_Architects_compressed-381.pdf
# 	Uploading blob for page 382 -> Azure_For_Architects_compressed-382.pdf
# 	Uploading blob for page 383 -> Azure_For_Architects_compressed-383.pdf
# 	Uploading blob for page 384 -> Azure_For_Architects_compressed-384.pdf
# 	Uploading blob for page 385 -> Azure_For_Architects_compressed-385.pdf
# 	Uploading blob for page 386 -> Azure_For_Architects_compressed-386.pdf
# 	Uploading blob for page 387 -> Azure_For_Architects_compressed-387.pdf
# 	Uploading blob for page 388 -> Azure_For_Architects_compressed-388.pdf
# 	Uploading blob for page 389 -> Azure_For_Architects_compressed-389.pdf
# 	Uploading blob for page 390 -> Azure_For_Architects_compressed-390.pdf
# 	Uploading blob for page 391 -> Azure_For_Architects_compressed-391.pdf
# 	Uploading blob for page 392 -> Azure_For_Architects_compressed-392.pdf
# 	Uploading blob for page 393 -> Azure_For_Architects_compressed-393.pdf
# 	Uploading blob for page 394 -> Azure_For_Architects_compressed-394.pdf
# 	Uploading blob for page 395 -> Azure_For_Architects_compressed-395.pdf
# 	Uploading blob for page 396 -> Azure_For_Architects_compressed-396.pdf
# 	Uploading blob for page 397 -> Azure_For_Architects_compressed-397.pdf
# 	Uploading blob for page 398 -> Azure_For_Architects_compressed-398.pdf
# 	Uploading blob for page 399 -> Azure_For_Architects_compressed-399.pdf
# 	Uploading blob for page 444 -> Azure_For_Architects_compressed-444.pdf
# 	Uploading blob for page 445 -> Azure_For_Architects_compressed-445.pdf
# 	Uploading blob for page 446 -> Azure_For_Architects_compressed-446.pdf
# 	Uploading blob for page 447 -> Azure_For_Architects_compressed-447.pdf
# 	Uploading blob for page 448 -> Azure_For_Architects_compressed-448.pdf
# 	Uploading blob for page 449 -> Azure_For_Architects_compressed-449.pdf
# 	Uploading blob for page 450 -> Azure_For_Architects_compressed-450.pdf
# 	Uploading blob for page 451 -> Azure_For_Architects_compressed-451.pdf
# 	Uploading blob for page 452 -> Azure_For_Architects_compressed-452.pdf
# 	Uploading blob for page 453 -> Azure_For_Architects_compressed-453.pdf
# 	Uploading blob for page 454 -> Azure_For_Architects_compressed-454.pdf
# 	Uploading blob for page 455 -> Azure_For_Architects_compressed-455.pdf
# 	Uploading blob for page 456 -> Azure_For_Architects_compressed-456.pdf
# 	Uploading blob for page 457 -> Azure_For_Architects_compressed-457.pdf
# 	Uploading blob for page 458 -> Azure_For_Architects_compressed-458.pdf
# 	Uploading blob for page 459 -> Azure_For_Architects_compressed-459.pdf
# 	Uploading blob for page 460 -> Azure_For_Architects_compressed-460.pdf
# 	Uploading blob for page 461 -> Azure_For_Architects_compressed-461.pdf
# 	Uploading blob for page 462 -> Azure_For_Architects_compressed-462.pdf
# 	Uploading blob for page 463 -> Azure_For_Architects_compressed-463.pdf
# 	Uploading blob for page 464 -> Azure_For_Architects_compressed-464.pdf
# 	Uploading blob for page 465 -> Azure_For_Architects_compressed-465.pdf
# 	Uploading blob for page 466 -> Azure_For_Architects_compressed-466.pdf
# 	Uploading blob for page 467 -> Azure_For_Architects_compressed-467.pdf
# 	Uploading blob for page 468 -> Azure_For_Architects_compressed-468.pdf
# 	Uploading blob for page 469 -> Azure_For_Architects_compressed-469.pdf
# 	Uploading blob for page 470 -> Azure_For_Architects_compressed-470.pdf
# 	Uploading blob for page 471 -> Azure_For_Architects_compressed-471.pdf
# 	Uploading blob for page 472 -> Azure_For_Architects_compressed-472.pdf
# 	Uploading blob for page 473 -> Azure_For_Architects_compressed-473.pdf
# 	Uploading blob for page 474 -> Azure_For_Architects_compressed-474.pdf
# 	Uploading blob for page 475 -> Azure_For_Architects_compressed-475.pdf
# 	Uploading blob for page 476 -> Azure_For_Architects_compressed-476.pdf
# 	Uploading blob for page 477 -> Azure_For_Architects_compressed-477.pdf
# 	Uploading blob for page 478 -> Azure_For_Architects_compressed-478.pdf
# 	Uploading blob for page 479 -> Azure_For_Architects_compressed-479.pdf
# 	Uploading blob for page 480 -> Azure_For_Architects_compressed-480.pdf
# 	Uploading blob for page 481 -> Azure_For_Architects_compressed-481.pdf
# 	Uploading blob for page 482 -> Azure_For_Architects_compressed-482.pdf
# 	Uploading blob for page 483 -> Azure_For_Architects_compressed-483.pdf
# 	Uploading blob for page 484 -> Azure_For_Architects_compressed-484.pdf
# 	Uploading blob for page 485 -> Azure_For_Architects_compressed-485.pdf
# 	Uploading blob for page 486 -> Azure_For_Architects_compressed-486.pdf
# 	Uploading blob for page 487 -> Azure_For_Architects_compressed-487.pdf
# 	Uploading blob for page 488 -> Azure_For_Architects_compressed-488.pdf
# 	Uploading blob for page 489 -> Azure_For_Architects_compressed-489.pdf
# 	Uploading blob for page 490 -> Azure_For_Architects_compressed-490.pdf
# 	Uploading blob for page 491 -> Azure_For_Architects_compressed-491.pdf
# 	Uploading blob for page 492 -> Azure_For_Architects_compressed-492.pdf
# 	Uploading blob for page 493 -> Azure_For_Architects_compressed-493.pdf
# 	Uploading blob for page 494 -> Azure_For_Architects_compressed-494.pdf
# 	Uploading blob for page 495 -> Azure_For_Architects_compressed-495.pdf
# 	Uploading blob for page 496 -> Azure_For_Architects_compressed-496.pdf
# 	Uploading blob for page 497 -> Azure_For_Architects_compressed-497.pdf
# 	Uploading blob for page 498 -> Azure_For_Architects_compressed-498.pdf
# 	Uploading blob for page 499 -> Azure_For_Architects_compressed-499.pdf
# 	Uploading blob for page 500 -> Azure_For_Architects_compressed-500.pdf
# 	Uploading blob for page 501 -> Azure_For_Architects_compressed-501.pdf
# 	Uploading blob for page 502 -> Azure_For_Architects_compressed-502.pdf
# 	Uploading blob for page 503 -> Azure_For_Architects_compressed-503.pdf
# 	Uploading blob for page 504 -> Azure_For_Architects_compressed-504.pdf
# 	Uploading blob for page 505 -> Azure_For_Architects_compressed-505.pdf
# 	Uploading blob for page 506 -> Azure_For_Architects_compressed-506.pdf
# 	Uploading blob for page 507 -> Azure_For_Architects_compressed-507.pdf
# 	Uploading blob for page 508 -> Azure_For_Architects_compressed-508.pdf
# 	Uploading blob for page 509 -> Azure_For_Architects_compressed-509.pdf
# 	Uploading blob for page 510 -> Azure_For_Architects_compressed-510.pdf
# 	Uploading blob for page 511 -> Azure_For_Architects_compressed-511.pdf
# 	Uploading blob for page 512 -> Azure_For_Architects_compressed-512.pdf
# 	Uploading blob for page 513 -> Azure_For_Architects_compressed-513.pdf
# 	Uploading blob for page 514 -> Azure_For_Architects_compressed-514.pdf
# 	Uploading blob for page 515 -> Azure_For_Architects_compressed-515.pdf
# 	Uploading blob for page 516 -> Azure_For_Architects_compressed-516.pdf
# 	Uploading blob for page 517 -> Azure_For_Architects_compressed-517.pdf
# 	Uploading blob for page 518 -> Azure_For_Architects_compressed-518.pdf
# 	Uploading blob for page 519 -> Azure_For_Architects_compressed-519.pdf
# 	Uploading blob for page 520 -> Azure_For_Architects_compressed-520.pdf
# 	Uploading blob for page 521 -> Azure_For_Architects_compressed-521.pdf
# 	Uploading blob for page 522 -> Azure_For_Architects_compressed-522.pdf
# 	Uploading blob for page 523 -> Azure_For_Architects_compressed-523.pdf
# 	Uploading blob for page 524 -> Azure_For_Architects_compressed-524.pdf
# 	Uploading blob for page 525 -> Azure_For_Architects_compressed-525.pdf
# 	Uploading blob for page 526 -> Azure_For_Architects_compressed-526.pdf
# 	Uploading blob for page 527 -> Azure_For_Architects_compressed-527.pdf
# 	Uploading blob for page 528 -> Azure_For_Architects_compressed-528.pdf
# 	Uploading blob for page 529 -> Azure_For_Architects_compressed-529.pdf
# 	Uploading blob for page 530 -> Azure_For_Architects_compressed-530.pdf
# 	Uploading blob for page 531 -> Azure_For_Architects_compressed-531.pdf
# 	Uploading blob for page 532 -> Azure_For_Architects_compressed-532.pdf
# 	Uploading blob for page 533 -> Azure_For_Architects_compressed-533.pdf
# 	Uploading blob for page 534 -> Azure_For_Architects_compressed-534.pdf
# 	Uploading blob for page 535 -> Azure_For_Architects_compressed-535.pdf
# 	Uploading blob for page 536 -> Azure_For_Architects_compressed-536.pdf
# 	Uploading blob for page 537 -> Azure_For_Architects_compressed-537.pdf
# 	Uploading blob for page 538 -> Azure_For_Architects_compressed-538.pdf
# 	Uploading blob for page 539 -> Azure_For_Architects_compressed-539.pdf
# 	Uploading blob for page 540 -> Azure_For_Architects_compressed-540.pdf
# 	Uploading blob for page 541 -> Azure_For_Architects_compressed-541.pdf
# 	Uploading blob for page 542 -> Azure_For_Architects_compressed-542.pdf
# 	Uploading blob for page 543 -> Azure_For_Architects_compressed-543.pdf
# 	Uploading blob for page 544 -> Azure_For_Architects_compressed-544.pdf
# 	Uploading blob for page 545 -> Azure_For_Architects_compressed-545.pdf
# 	Uploading blob for page 546 -> Azure_For_Architects_compressed-546.pdf
# 	Uploading blob for page 547 -> Azure_For_Architects_compressed-547.pdf
# 	Uploading blob for page 548 -> Azure_For_Architects_compressed-548.pdf
# 	Uploading blob for page 549 -> Azure_For_Architects_compressed-549.pdf
# 	Uploading blob for page 550 -> Azure_For_Architects_compressed-550.pdf
# 	Uploading blob for page 551 -> Azure_For_Architects_compressed-551.pdf
# 	Uploading blob for page 552 -> Azure_For_Architects_compressed-552.pdf
# 	Uploading blob for page 553 -> Azure_For_Architects_compressed-553.pdf
# 	Uploading blob for page 554 -> Azure_For_Architects_compressed-554.pdf
# 	Uploading blob for page 555 -> Azure_For_Architects_compressed-555.pdf
# 	Uploading blob for page 556 -> Azure_For_Architects_compressed-556.pdf
# 	Uploading blob for page 557 -> Azure_For_Architects_compressed-557.pdf
# 	Uploading blob for page 558 -> Azure_For_Architects_compressed-558.pdf
# 	Uploading blob for page 559 -> Azure_For_Architects_compressed-559.pdf
# 	Uploading blob for page 560 -> Azure_For_Architects_compressed-560.pdf
# 	Uploading blob for page 561 -> Azure_For_Architects_compressed-561.pdf
# 	Uploading blob for page 562 -> Azure_For_Architects_compressed-562.pdf
# 	Uploading blob for page 563 -> Azure_For_Architects_compressed-563.pdf
# 	Uploading blob for page 564 -> Azure_For_Architects_compressed-564.pdf
# 	Uploading blob for page 565 -> Azure_For_Architects_compressed-565.pdf
# 	Uploading blob for page 566 -> Azure_For_Architects_compressed-566.pdf
# 	Uploading blob for page 567 -> Azure_For_Architects_compressed-567.pdf
# 	Uploading blob for page 568 -> Azure_For_Architects_compressed-568.pdf
# 	Uploading blob for page 569 -> Azure_For_Architects_compressed-569.pdf
# 	Uploading blob for page 570 -> Azure_For_Architects_compressed-570.pdf
# 	Uploading blob for page 571 -> Azure_For_Architects_compressed-571.pdf
# 	Uploading blob for page 572 -> Azure_For_Architects_compressed-572.pdf
# 	Uploading blob for page 573 -> Azure_For_Architects_compressed-573.pdf
# 	Uploading blob for page 574 -> Azure_For_Architects_compressed-574.pdf
# 	Uploading blob for page 575 -> Azure_For_Architects_compressed-575.pdf
# 	Uploading blob for page 576 -> Azure_For_Architects_compressed-576.pdf
# 	Uploading blob for page 577 -> Azure_For_Architects_compressed-577.pdf
# 	Uploading blob for page 578 -> Azure_For_Architects_compressed-578.pdf
# 	Uploading blob for page 579 -> Azure_For_Architects_compressed-579.pdf
# 	Uploading blob for page 580 -> Azure_For_Architects_compressed-580.pdf
# 	Uploading blob for page 581 -> Azure_For_Architects_compressed-581.pdf
# 	Uploading blob for page 582 -> Azure_For_Architects_compressed-582.pdf
# 	Uploading blob for page 583 -> Azure_For_Architects_compressed-583.pdf
# 	Uploading blob for page 584 -> Azure_For_Architects_compressed-584.pdf
# 	Uploading blob for page 585 -> Azure_For_Architects_compressed-585.pdf
# 	Uploading blob for page 586 -> Azure_For_Architects_compressed-586.pdf
# 	Uploading blob for page 587 -> Azure_For_Architects_compressed-587.pdf
# 	Uploading blob for page 588 -> Azure_For_Architects_compressed-588.pdf
# 	Uploading blob for page 589 -> Azure_For_Architects_compressed-589.pdf
# 	Uploading blob for page 590 -> Azure_For_Architects_compressed-590.pdf
# 	Uploading blob for page 591 -> Azure_For_Architects_compressed-591.pdf
# 	Uploading blob for page 592 -> Azure_For_Architects_compressed-592.pdf
# 	Uploading blob for page 593 -> Azure_For_Architects_compressed-593.pdf
# 	Uploading blob for page 594 -> Azure_For_Architects_compressed-594.pdf
# 	Uploading blob for page 595 -> Azure_For_Architects_compressed-595.pdf
# 	Uploading blob for page 596 -> Azure_For_Architects_compressed-596.pdf
# 	Uploading blob for page 597 -> Azure_For_Architects_compressed-597.pdf
# 	Uploading blob for page 598 -> Azure_For_Architects_compressed-598.pdf
# 	Uploading blob for page 599 -> Azure_For_Architects_compressed-599.pdf
# 	Uploading blob for page 600 -> Azure_For_Architects_compressed-600.pdf
# 	Uploading blob for page 601 -> Azure_For_Architects_compressed-601.pdf
# 	Uploading blob for page 602 -> Azure_For_Architects_compressed-602.pdf
# 	Uploading blob for page 603 -> Azure_For_Architects_compressed-603.pdf
# 	Uploading blob for page 604 -> Azure_For_Architects_compressed-604.pdf
# 	Uploading blob for page 605 -> Azure_For_Architects_compressed-605.pdf
# 	Uploading blob for page 606 -> Azure_For_Architects_compressed-606.pdf
# 	Uploading blob for page 607 -> Azure_For_Architects_compressed-607.pdf
# 	Uploading blob for page 608 -> Azure_For_Architects_compressed-608.pdf
# 	Uploading blob for page 609 -> Azure_For_Architects_compressed-609.pdf
# 	Uploading blob for page 610 -> Azure_For_Architects_compressed-610.pdf
# 	Uploading blob for page 611 -> Azure_For_Architects_compressed-611.pdf
# 	Uploading blob for page 612 -> Azure_For_Architects_compressed-612.pdf
# 	Uploading blob for page 613 -> Azure_For_Architects_compressed-613.pdf
# 	Uploading blob for page 614 -> Azure_For_Architects_compressed-614.pdf
# 	Uploading blob for page 615 -> Azure_For_Architects_compressed-615.pdf
# 	Uploading blob for page 616 -> Azure_For_Architects_compressed-616.pdf
# 	Uploading blob for page 617 -> Azure_For_Architects_compressed-617.pdf
# 	Uploading blob for page 618 -> Azure_For_Architects_compressed-618.pdf
# 	Uploading blob for page 619 -> Azure_For_Architects_compressed-619.pdf
# 	Uploading blob for page 620 -> Azure_For_Architects_compressed-620.pdf
# 	Uploading blob for page 621 -> Azure_For_Architects_compressed-621.pdf
# 	Uploading blob for page 622 -> Azure_For_Architects_compressed-622.pdf
# 	Uploading blob for page 623 -> Azure_For_Architects_compressed-623.pdf
# 	Uploading blob for page 624 -> Azure_For_Architects_compressed-624.pdf
# 	Uploading blob for page 625 -> Azure_For_Architects_compressed-625.pdf
# 	Uploading blob for page 626 -> Azure_For_Architects_compressed-626.pdf
# 	Uploading blob for page 627 -> Azure_For_Architects_compressed-627.pdf
# 	Uploading blob for page 628 -> Azure_For_Architects_compressed-628.pdf
# 	Uploading blob for page 629 -> Azure_For_Architects_compressed-629.pdf
# 	Uploading blob for page 630 -> Azure_For_Architects_compressed-630.pdf
# 	Uploading blob for page 631 -> Azure_For_Architects_compressed-631.pdf
# 	Uploading blob for page 632 -> Azure_For_Architects_compressed-632.pdf
# 	Uploading blob for page 633 -> Azure_For_Architects_compressed-633.pdf
# 	Uploading blob for page 634 -> Azure_For_Architects_compressed-634.pdf
# 	Uploading blob for page 635 -> Azure_For_Architects_compressed-635.pdf
# 	Uploading blob for page 636 -> Azure_For_Architects_compressed-636.pdf
# 	Uploading blob for page 637 -> Azure_For_Architects_compressed-637.pdf
# 	Uploading blob for page 638 -> Azure_For_Architects_compressed-638.pdf
# 	Uploading blob for page 639 -> Azure_For_Architects_compressed-639.pdf
# 	Uploading blob for page 640 -> Azure_For_Architects_compressed-640.pdf
# 	Uploading blob for page 641 -> Azure_For_Architects_compressed-641.pdf
# 	Uploading blob for page 642 -> Azure_For_Architects_compressed-642.pdf
# 	Uploading blob for page 643 -> Azure_For_Architects_compressed-643.pdf
# 	Uploading blob for page 644 -> Azure_For_Architects_compressed-644.pdf
# 	Uploading blob for page 645 -> Azure_For_Architects_compressed-645.pdf
# 	Uploading blob for page 646 -> Azure_For_Architects_compressed-646.pdf
# 	Uploading blob for page 647 -> Azure_For_Architects_compressed-647.pdf
# 	Uploading blob for page 648 -> Azure_For_Architects_compressed-648.pdf
# 	Uploading blob for page 649 -> Azure_For_Architects_compressed-649.pdf
# 	Uploading blob for page 650 -> Azure_For_Architects_compressed-650.pdf
# 	Uploading blob for page 651 -> Azure_For_Architects_compressed-651.pdf
# 	Uploading blob for page 652 -> Azure_For_Architects_compressed-652.pdf
# 	Uploading blob for page 653 -> Azure_For_Architects_compressed-653.pdf
# 	Uploading blob for page 654 -> Azure_For_Architects_compressed-654.pdf
# 	Uploading blob for page 655 -> Azure_For_Architects_compressed-655.pdf
# 	Uploading blob for page 656 -> Azure_For_Architects_compressed-656.pdf
# 	Uploading blob for page 657 -> Azure_For_Architects_compressed-657.pdf
# 	Uploading blob for page 658 -> Azure_For_Architects_compressed-658.pdf
# 	Uploading blob for page 659 -> Azure_For_Architects_compressed-659.pdf
# 	Uploading blob for page 660 -> Azure_For_Architects_compressed-660.pdf
# 	Uploading blob for page 661 -> Azure_For_Architects_compressed-661.pdf
# 	Uploading blob for page 662 -> Azure_For_Architects_compressed-662.pdf
# 	Uploading blob for page 663 -> Azure_For_Architects_compressed-663.pdf
# 	Uploading blob for page 664 -> Azure_For_Architects_compressed-664.pdf
# 	Uploading blob for page 665 -> Azure_For_Architects_compressed-665.pdf
# 	Uploading blob for page 666 -> Azure_For_Architects_compressed-666.pdf
# 	Uploading blob for page 667 -> Azure_For_Architects_compressed-667.pdf
# 	Uploading blob for page 668 -> Azure_For_Architects_compressed-668.pdf
# 	Uploading blob for page 669 -> Azure_For_Architects_compressed-669.pdf
# 	Uploading blob for page 670 -> Azure_For_Architects_compressed-670.pdf
# 	Uploading blob for page 671 -> Azure_For_Architects_compressed-671.pdf
# 	Uploading blob for page 672 -> Azure_For_Architects_compressed-672.pdf
# 	Uploading blob for page 673 -> Azure_For_Architects_compressed-673.pdf
# 	Uploading blob for page 674 -> Azure_For_Architects_compressed-674.pdf
# 	Uploading blob for page 675 -> Azure_For_Architects_compressed-675.pdf
# 	Uploading blob for page 676 -> Azure_For_Architects_compressed-676.pdf
# 	Uploading blob for page 677 -> Azure_For_Architects_compressed-677.pdf
# 	Uploading blob for page 678 -> Azure_For_Architects_compressed-678.pdf
# 	Uploading blob for page 679 -> Azure_For_Architects_compressed-679.pdf
# 	Uploading blob for page 680 -> Azure_For_Architects_compressed-680.pdf
# 	Uploading blob for page 681 -> Azure_For_Architects_compressed-681.pdf
# 	Uploading blob for page 682 -> Azure_For_Architects_compressed-682.pdf
# 	Uploading blob for page 683 -> Azure_For_Architects_compressed-683.pdf
# 	Uploading blob for page 684 -> Azure_For_Architects_compressed-684.pdf
# 	Uploading blob for page 685 -> Azure_For_Architects_compressed-685.pdf
# 	Uploading blob for page 686 -> Azure_For_Architects_compressed-686.pdf
# 	Uploading blob for page 687 -> Azure_For_Architects_compressed-687.pdf
# 	Uploading blob for page 688 -> Azure_For_Architects_compressed-688.pdf
# 	Uploading blob for page 689 -> Azure_For_Architects_compressed-689.pdf
# 	Uploading blob for page 690 -> Azure_For_Architects_compressed-690.pdf
# 	Uploading blob for page 691 -> Azure_For_Architects_compressed-691.pdf
# 	Uploading blob for page 692 -> Azure_For_Architects_compressed-692.pdf
# 	Uploading blob for page 693 -> Azure_For_Architects_compressed-693.pdf
# 	Uploading blob for page 694 -> Azure_For_Architects_compressed-694.pdf
# 	Uploading blob for page 695 -> Azure_For_Architects_compressed-695.pdf
# 	Uploading blob for page 696 -> Azure_For_Architects_compressed-696.pdf
# 	Uploading blob for page 697 -> Azure_For_Architects_compressed-697.pdf
# 	Uploading blob for page 698 -> Azure_For_Architects_compressed-698.pdf
# 	Uploading blob for page 699 -> Azure_For_Architects_compressed-699.pdf
# 	Uploading blob for page 700 -> Azure_For_Architects_compressed-700.pdf
# Indexing sections from 'C:\Users\srely\Repos\AZURE-AI-SEARCH\Data\Azure_For_Architects_compressed.pdf' into search index 'test'
# Splitting 'C:\Users\srely\Repos\AZURE-AI-SEARCH\Data\Azure_For_Architects_compressed.pdf' into sections
# 	Indexed 1000 sections, 1000 succeeded
# 	Indexed 82 sections, 82 succeeded
