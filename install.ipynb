# %%
# !python -m venv azureaisearch_env

# %%
# %pip install -r requirements.txt
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/244.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/244.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/244.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/244.0 kB 330.3 kB/s eta 0:00:01
#      ------------- ----------------------- 92.2/244.0 kB 581.0 kB/s eta 0:00:01
#      -------------------------------------- 244.0/244.0 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/144.2 kB ? eta -:--:--
#      -------------------------------------- 144.2/144.2 kB 8.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/296.7 kB ? eta -:--:--
#      -------------------------------------- 296.7/296.7 kB 9.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/228.6 kB ? eta -:--:--
#      ---------------------------------------- 228.6/228.6 kB ? eta 0:00:00
# ...
