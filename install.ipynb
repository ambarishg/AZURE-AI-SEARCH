# %%
# %pip install -r requirements.txt
# Out:
# ...
#      -------------------------------------- 244.0/244.0 kB 5.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 144.2/144.2 kB 8.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 296.7/296.7 kB 19.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 228.6/228.6 kB 13.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 383.2/383.2 kB 24.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 85.4/85.4 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 83.5/83.5 kB 4.6 MB/s eta 0:00:00
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# ...
#      ---------------------------------------- 4.8/4.8 MB 25.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 82.0/82.0 kB ? eta 0:00:00
# ...
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#    --------------------------------------- 226.1/226.1 kB 13.5 MB/s eta 0:00:00
# ...
